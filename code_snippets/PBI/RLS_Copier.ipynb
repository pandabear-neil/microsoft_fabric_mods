# %% [markdown]
# # RLS Copier for Power BI Semantic Models
# This notebook automates copying Row-Level Security (RLS) configuration
# from a reference semantic model to a target semantic model.
#
# **What it does**
# - Compare RLS role definitions between two models
# - Replace target role definitions when needed
# - Copy role members from a reference model to a target model
# - Create a backup before applying changes
# - Support dry-run mode for validation
#
# **Current limitations**
# - Mixed/composite storage models are not supported
# - Backup behavior assumes a default report can be cloned for 'Import' and 'DirectQuery' storage modes
#
# **Notes**
# - Dry-run mode is recommended before any write operation
# - This utility is intended for controlled administrative scenarios
#
# **Version**: 1.0.0
#
# **Last updated**: 2026-03-16

# %% [markdown]
# # PARAMETERS

# %%
# Target semantic model (roles and members will be updated here)
MODEL = "TARGET_MODEL_NAME"
MODEL_WORKSPACE = "TARGET_WORKSPACE_NAME"

# Reference semantic model (roles and members will be copied from here)
REF_MODEL = "REFERENCE_MODEL_NAME"
REF_WORKSPACE = "REFERENCE_WORKSPACE_NAME"

# Optional backup folder in the target workspace
BACKUP_FOLDER = "BACKUP_FOLDER_NAME"

# Safety switch: start with True when validating behavior
DRY_RUN = True

# %% [markdown]
# # IMPORTS

# %%
# %pip install -q semantic-link-labs==0.13.2
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dataclasses import dataclass, field
from datetime import datetime, tzinfo
from typing import Literal

import pytz
import pandas as pd
import sempy.fabric as fabric
import notebookutils as nbutl
from sempy_labs.tom import connect_semantic_model
from sempy_labs import get_semantic_model_bim, create_semantic_model_from_bim
from sempy_labs.report import clone_report

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # FUNCTIONS

# %% [markdown]
# ## Read Operations

# %%
def get_roles_df(model: str, workspace: str = None, include_members: bool = False) -> pd.DataFrame:
    """
    Return semantic model roles as a DataFrame, optionally include role members.

    Args:
        model: Semantic model name or ID.
        workspace: Workspace name or ID.
        include_members: If True, include one row per role member.

    Returns:
        A pandas DataFrame containing role metadata. If `include_members=True`,
        member details are included in the output.

    Example:
        >>> roles_df = get_roles_df("model_a", "workspace_a", include_members=True)
        >>> display(roles_df)
    """

    roles_data = []

    with connect_semantic_model(dataset=model, workspace=workspace, readonly=True) as tom:
        for r in tom.model.Roles:
            role_data = {
                "Role": r.Name, 
                "Description": r.Description, 
                "Model Permission": str(r.ModelPermission), 
                "Modified Time": r.ModifiedTime
            }
            if include_members:
                for m in r.Members:
                    roles_data.append({
                        **role_data,
                        "Member":m.MemberName, 
                        "Identity Provider": m.IdentityProvider
                    })
            else:
                roles_data.append(role_data)
    return pd.DataFrame(roles_data)

# %%
def get_role_definition(model: str, workspace: str = None) -> list[dict]:
    """
    Return RLS role definitions from a semantic model.

    Args:
        model: Semantic model name or ID.
        workspace: Workspace name or ID.

    Returns:
        A list of dictionaries containing role names, role permission, 
        table names, and filter expressions.

    Example:
        >>> role_defs = get_role_definition("model_a", "workspace_a")
        >>> for item in role_defs:
        ...     print(item["Role"], item["Table"])
    """
    with connect_semantic_model(dataset=model, workspace=workspace, readonly=True) as tom:
        model_rls = [
            {
                "Role": r.Role.Name, 
                "ModelPermission": str(r.Role.ModelPermission), 
                "Table": r.Table.Name, 
                "FilterExpression": r.FilterExpression
            } for r in tom.all_rls()
        ]
    return model_rls

# %%
def get_role_members(model: str, workspace: str, output_option: str = 'list') -> list[dict] | pd.DataFrame:
    """
    Return role members from a semantic model.

    Args:
        model: Semantic model name or ID.
        workspace: Workspace name or ID.
        output_option: Output format. Use `"list"` for a list of dictionaries
            or `"df"` for a pandas DataFrame.

    Returns:
        Role member details as either a list of dictionaries or a DataFrame.

    Example:
        >>> members_x = get_role_members("model_a", "workspace_a", output_option="list")
        >>> display(members_x)
    """
    rows = []
    
    with connect_semantic_model(
        dataset=model,
        workspace=workspace,
        readonly=True
    ) as tom:
        for role in tom.model.Roles:
            for member in role.Members:
                member_type = str(member.MemberType).split(".")[-1]
                rows.append({
                    "role_name": role.Name,
                    "member_name": member.MemberName,
                    "member_type": member_type
                })
    
    if output_option == 'df':
        return pd.DataFrame(rows)
    return rows

# %%
def get_storage_mode(model: str, workspace: str = None) -> str | list[str]:
    """
    Return the storage mode used by a semantic model.

    Args:
        model: Semantic model name or ID.
        workspace: Workspace name or ID.

    Returns:
        The storage mode as a string.

    Raises:
        ValueError: If no storage mode is found, multiple modes are detected,
            or the mode is unsupported.

    Example:
        >>> mode_x = get_storage_mode("model_a", "workspace_a")
        >>> print(mode_x)
    """
    supported_modes = {"Import", "DirectLake", "DirectQuery"}

    with connect_semantic_model(dataset=model, workspace=workspace, readonly=True) as tom:
        modes = set()
        for table in tom.model.Tables:
            for part in table.Partitions:
                # Normalize to string once
                mode = str(part.Mode)
                modes.add(mode)

                # Early exit if mixed modes detected
                if len(modes) > 1:
                    raise ValueError(
                        f"Multiple storage modes detected: {sorted(modes)}. Mixed models not supported."
                    )

    if not modes:
        raise ValueError("Storage mode not found.")

    mode = modes.pop()

    if mode not in supported_modes:
        raise ValueError(f"Unsupported storage mode: {mode}")

    return mode

# %% [markdown]
# ## Audit & Compare

# %%
def compare_roles(
    target_model: str,
    target_workspace: str,
    ref_model: str,
    ref_workspace: str,
    include_role_def: bool = True
) -> tuple[bool, dict]:
    """
    Compare roles between a target model and a reference model.

    Args:
        target_model: Target semantic model name or ID.
        target_workspace: Target workspace name or ID.
        ref_model: Reference semantic model name or ID.
        ref_workspace: Reference workspace name or ID.
        include_role_def: If True, compare role definitions. Otherwise,
            compare role names only (including roles without role definitions).

    Returns:
        A tuple containing:
        - A boolean indicating whether differences were found
        - A dictionary describing reference-only, target-only, and shared roles

    Example:
        >>> has_diff, comparison_x = compare_roles(
        ...     target_model="model_a",
        ...     target_workspace="workspace_a",
        ...     ref_model="model_b",
        ...     ref_workspace="workspace_b",
        ...     include_role_def=True
        ... )
        >>> print(has_diff)
        >>> print(comparison_x)
    """
    def group_by_role(rows: list[dict]) -> dict[str, dict]:
        """
        Convert raw role definition rows into:

        {
            role_name: {
                hashable_definition: original_definition_dict
            }
        }
        """
        grouped = {}

        for row in rows:
            role = row["Role"]
            definition = {k: v for k, v in row.items() if k != "Role"}
            # Make hashable key for set comparison
            key = tuple(sorted(definition.items()))
            grouped.setdefault(role, {})[key] = definition
        return grouped

    # ---------------------------------------------------
    # Case 1: Compare role definitions
    # ---------------------------------------------------
    if include_role_def:
        ref_raw = get_role_definition(
            model=ref_model,
            workspace=ref_workspace
        )

        target_raw = get_role_definition(
            model=target_model,
            workspace=target_workspace
        )

        ref_grouped = group_by_role(ref_raw)
        target_grouped = group_by_role(target_raw)

        all_roles = sorted(set(ref_grouped) | set(target_grouped))

        comparison_dict = {
            "reference_only": [],
            "target_only": [],
            "shared": []
        }

        for role in all_roles:

            ref_defs = ref_grouped.get(role, {})
            target_defs = target_grouped.get(role, {})

            ref_keys = set(ref_defs)
            target_keys = set(target_defs)

            ref_only = ref_keys - target_keys
            target_only = target_keys - ref_keys
            shared = ref_keys & target_keys

            if ref_only:
                comparison_dict["reference_only"].append({
                    "role": role,
                    "definitions": [ref_defs[k] for k in sorted(ref_only)]
                })

            if target_only:
                comparison_dict["target_only"].append({
                    "role": role,
                    "definitions": [target_defs[k] for k in sorted(target_only)]
                })

            if shared:
                comparison_dict["shared"].append({
                    "role": role,
                    "definitions": [ref_defs[k] for k in sorted(shared)]
                })

    # ---------------------------------------------------
    # Case 2: Compare role names only
    # ---------------------------------------------------
    else:
        ref_roles = set(get_roles_df(ref_model, ref_workspace)["Role"])
        target_roles = set(get_roles_df(target_model, target_workspace)["Role"])

        comparison_dict = {
            "reference_only": sorted(ref_roles - target_roles),
            "target_only": sorted(target_roles - ref_roles),
            "shared": sorted(ref_roles & target_roles)
        }

    has_differences = bool(comparison_dict["reference_only"] or comparison_dict["target_only"])

    return has_differences, comparison_dict

# %% [markdown]
# ## Modify Operations

# %%
def copy_role(
    target_model: str,
    target_workspace: str,
    ref_model: str,
    ref_workspace: str,
    dry_run: bool = True
) -> list[dict]:
    """
    Copy role definitions from a reference model to a target model.

    Args:
        target_model: Target semantic model name or ID.
        target_workspace: Target workspace name or ID.
        ref_model: Reference semantic model name or ID.
        ref_workspace: Reference workspace name or ID.
        dry_run: If True, print the planned changes without modifying the target.

    Returns:
        A list of role definitions that were copied or would be copied.

    Example:
        >>> preview_x = copy_role(
        ...     "model_a",
        ...     "workspace_a",
        ...     "model_b",
        ...     "workspace_b",
        ...     dry_run=True
        ... )
        >>> display(preview_x)
    """
    # Get reference roles
    ref_role_defs = get_role_definition(ref_model, ref_workspace)

    if dry_run:
        print("DRY RUN - No changes will be made")
        print(f"Would copy {len(ref_role_defs)} roles (with valid role definitions) from '{ref_model}' to '{target_model}'")

        for role in ref_role_defs[:10]:
            print(f"  - {role['Role']}: {role['Table']} - {role.get('FilterExpression', 'N/A')}")
        if len(ref_role_defs) > 10:
            print(f"  ... and {len(ref_role_defs) - 10} more")
        return ref_role_defs

    # Execute copy
    with connect_semantic_model(dataset=target_model, workspace=target_workspace, readonly=False) as tom:
        existing_roles = {r.Name for r in tom.model.Roles}

        for role_def in ref_role_defs:
            role_name = role_def["Role"]

            if role_name not in existing_roles:
                tom.add_role(
                    role_name=role_name, 
                    model_permission=role_def["ModelPermission"]
                )
                existing_roles.add(role_name)

            if role_def.get("FilterExpression"):
                tom.set_rls(
                    role_name=role_name,
                    table_name=role_def["Table"],
                    filter_expression=role_def["FilterExpression"]
                )

    print(f"Copied {len(ref_role_defs)} role definitions from [{ref_model}] to [{target_model}]")
    return ref_role_defs

# %%
def remove_role(
    model: str,
    workspace: str,
    remove_all: bool = False,
    remove_roles: list[str] = None,
    dry_run: bool = True
) -> list[str]:
    """
    Remove roles from a semantic model.

    Args:
        model: Semantic model name or ID.
        workspace: Workspace name or ID.
        remove_all: If True, remove all roles.
        remove_roles: Specific role names to remove.
        dry_run: If True, print the planned changes without modifying the model.

    Returns:
        A list of role names that were removed or would be removed.

    Example:
        >>> removed_x = remove_role(
        ...     "model_a",
        ...     "workspace_a",
        ...     remove_all=True,
        ...     dry_run=True
        ... )
        >>> print(removed_x)
    """
    # Determine what to remove
    if remove_all:
        roles_df = get_roles_df(model, workspace)
        if roles_df.empty:
            print("No roles to remove")
            return []    

        to_remove = roles_df["Role"].tolist()
    elif remove_roles:
        to_remove = remove_roles
    else:
        print("No roles to remove")
        return []
    
    if dry_run:
        print("DRY RUN - No changes will be made")
        print(f"Would remove {len(to_remove)} roles from '{model}':")
        for role in to_remove[:10]:  # Show first 10
            print(f"  - {role}")
        if len(to_remove) > 10:
            print(f"  ... and {len(to_remove) - 10} more")
        return to_remove
    
    # Execute removal
    print(f"Removing {len(to_remove)} roles from '{model}'...")
    removed_count = 0
    
    with connect_semantic_model(dataset=model, workspace=workspace, readonly=False) as tom:
        for role_name in to_remove:
            try:
                tom.model.Roles.Remove(role_name)
                removed_count += 1
            except Exception as e:
                print(f"Failed to remove role '{role_name}': {str(e)}")
    
    print(f"Removed {removed_count}/{len(to_remove)} roles")
    return to_remove

# %%
def add_role_members(
    model: str,
    workspace: str,
    add_members: list[dict],
    dry_run: bool = True
) -> list[dict]:
    """
    Add role members to a semantic model.

    Args:
        model: Semantic model name or ID.
        workspace: Workspace name or ID.
        add_members: Member records with `role_name`, `member_name`,
            and `member_type`.
        dry_run: If True, print the planned changes without modifying the model.

    Returns:
        A list of members that were added or would be added.

    Example:
        >>> members_x = [
        ...     {
        ...         "role_name": "role_alpha",
        ...         "member_name": "principal_alpha",
        ...         "member_type": "User"
        ...     }
        ... ]
        >>> added_x = add_role_members(
        ...     "model_a",
        ...     "workspace_a",
        ...     members_x,
        ...     dry_run=True
        ... )
        >>> print(added_x)
    """
    if not add_members:
        print("No members to add")
        return []
    
    if dry_run:
        print("DRY RUN - No changes will be made")
        print(f"Would add {len(add_members)} members to '{model}':")
        
        for m in add_members[:10]:  # Show first 10
            print(f"  + {m['role_name']}: {m['member_name']} ({m['member_type']})")
        
        if len(add_members) > 10:
            print(f"  ... and {len(add_members) - 10} more")

        return add_members
    
    # Execute addition
    print(f"Adding {len(add_members)} members to '{model}'...")
    added_count = 0
    
    with connect_semantic_model(dataset=model, workspace=workspace, readonly=False) as tom:
        for m in add_members:
            try:
                tom.add_role_member(
                    role_name=m["role_name"],
                    member=m["member_name"],
                    role_member_type=m["member_type"]
                )
                added_count += 1
            except Exception as e:
                print(f"🟡 Failed to add '{m['member_name']}' to '{m['role_name']}': {model} may not have a valid role definition")
    
    print(f"Added {added_count}/{len(add_members)} members")
    return add_members

# %%
def remove_role_members(
    model: str, 
    workspace: str, 
    remove_all: bool = False, 
    remove_members: list[dict] = None, 
    dry_run: bool = True
) -> list[dict]:
    """
    Remove role members from a semantic model.

    Args:
        model: Semantic model name or ID.
        workspace: Workspace name or ID.
        remove_all: If True, remove all role members.
        remove_members: Specific member records to remove.
        dry_run: If True, print the planned changes without modifying the model.

    Returns:
        A list of members that were removed or would be removed.

    Example:
        >>> removed_x = remove_role_members(
        ...     "model_a",
        ...     "workspace_a",
        ...     remove_all=True,
        ...     dry_run=True
        ... )
        >>> print(removed_x)
    """
    # Determine what to remove
    if remove_all:
        to_remove = get_role_members(model, workspace, output_option="list")
    elif remove_members:
        to_remove = remove_members
    else:
        print("No members to remove")
        return []
    
    if dry_run:
        print("DRY RUN - No changes will be made")
        print(f"Would remove {len(to_remove)} members from '{model}':")

        for m in to_remove[:10]:  # Show first 10
            print(f"  - {m['role_name']}: {m['member_name']} ({m['member_type']})")
        
        if len(to_remove) > 10:
            print(f"  ... and {len(to_remove) - 10} more")
        
        return to_remove
    
    # Execute removal
    print(f"Removing {len(to_remove)} members from '{model}'...")
    removed_count = 0
    
    with connect_semantic_model(dataset=model, workspace=workspace, readonly=False) as tom:
        for m in to_remove:
            try:
                tom.remove_role_member(
                    role_name=m["role_name"],
                    member=m["member_name"]
                )
                removed_count += 1
            except Exception as e:
                print(f"Failed to remove {m['member_name']}: {str(e)}")
    
    print(f"Removed {removed_count}/{len(to_remove)} members")
    return to_remove

# %% [markdown]
# ## Backup Operations

# %%
def move_items_to_folder(
    item_ids: list[str],
    folder: str = None,
    workspace: str = None,
    dry_run: bool = True
) -> dict | None:
    """
    Move workspace items to a folder in bulk.

    Args:
        item_ids: Item IDs to move.
        folder: Target folder name or path.
        workspace: Workspace name or ID.
        dry_run: If True, print the planned changes without moving items.

    Returns:
        The API response as a dictionary, or `None` in dry-run mode.

    Example:
        >>> ids_x = ["item_alpha", "item_beta"]
        >>> result_x = move_items_to_folder(
        ...     item_ids=ids_x,
        ...     folder="folder_a",
        ...     workspace="workspace_a",
        ...     dry_run=True
        ... )
        >>> print(result_x)
    """ 
    if not item_ids:
        print("No items to move")
        return None
    
    # Resolve workspace
    workspace_name, workspace_id = fabric.resolve_workspace_name_and_id(workspace)

    # Resolve environment
    try:
        folder_id = fabric.resolve_folder_id(folder, workspace)
        folder_path = fabric.resolve_folder_path(folder, workspace)
        folder_exists = True
    except Exception as e:
        folder_id = None
        folder_path = f"{folder}" if folder else ""
        folder_exists = False
        # Only create folder when actually executing
        if not dry_run:
            print(f"Creating folder '{folder}'...")
            folder_id = fabric.create_folder(folder, workspace, recursive=True)
            folder_exists = True
    
    if dry_run:
        print("DRY RUN - No changes will be made")
        if not folder_exists:
            print(f"Folder '{folder}' does not exist - would be created")
        print(f"Would move {len(item_ids)} items to [{workspace_name}/{folder_path}]")
        print(f"Items to move:")
        for item_id in item_ids[:10]:  # Show first 10
            print(f"  - {item_id}")
        if len(item_ids) > 10:
            print(f"  ... and {len(item_ids) - 10} more")
        return None

    
    # Execute move
    print(f"Moving {len(item_ids)} items to [{workspace_name}/{folder_path}]...")
    
    payload = {
        'items': item_ids,
        'targetFolderId': folder_id if folder_id else None
    }
    
    try:
        client = fabric.FabricRestClient()
        response = client.post(f"v1/workspaces/{workspace_id}/items/bulkMove", json=payload)
        print(f"Moved {len(item_ids)} items to [{workspace_name}/{folder_path}]")
        return response.json()
    except Exception as e:
        print(f"Failed to move items: {str(e)}")
        return None

# %%
def backup_model(
    model: str,
    model_workspace: str,
    backup_workspace: str,
    backup_folder: str | None = None,
    storage_mode: str | None = None,
    backup_prefix: str = "Backup",
    timezone: str = "UTC",
    dry_run: bool = True,
) -> dict | None:
    """
    Create a backup of a semantic model and, when applicable, its report.

    Args:
        model: Source semantic model name or ID.
        model_workspace: Source workspace name or ID.
        backup_workspace: Backup workspace name or ID.
        backup_folder: Optional backup folder name or path.
        storage_mode: Storage mode override. If not provided, it is detected.
        backup_prefix: Prefix used for backup item names.
        timezone: Timezone used for the backup timestamp.
        dry_run: If True, print the planned changes without creating a backup.

    Returns:
        A dictionary with backup details, or `None` if no backup is created.

    Example:
        >>> backup_x = backup_model(
        ...     model="model_a",
        ...     model_workspace="workspace_a",
        ...     backup_workspace="workspace_b",
        ...     backup_folder="folder_a",
        ...     storage_mode="Import",
        ...     dry_run=True
        ... )
        >>> print(backup_x)
    """

    # Resolve Storage Mode
    if not storage_mode:
        storage_mode = get_storage_mode(model, model_workspace)

    backup_model_and_report = storage_mode != "DirectLake"

    # Prepare backup name
    timestamp = datetime.now(pytz.timezone(timezone)).strftime("%Y%m%dT%H%M%S")
    backup_name = f"{backup_prefix}_{model}_{timestamp}"
    
    if dry_run:
        print("DRY RUN - No changes will be made")
        print("Would create backup:")
        print(f"    Source: {model}")
        print(f"    Backup name: {backup_name}")
        print(f"    Workspace: {backup_workspace}")
        if backup_folder:
            print(f"    Folder: {backup_folder}")
        print(f"    Storage mode: {storage_mode}")
        print("    Items: Semantic model + Report" if backup_model_and_report else "Items: Semantic model only")
        return None

    print(f"Creating backup: '{model}' -> '{backup_name}'...")

    try:
        # Export semantic model as BIM
        print(f"Exporting BIM from '{model}'...")
        bim_file = get_semantic_model_bim(dataset=model, workspace=model_workspace)

        # Create backup semantic model
        print("Creating backup semantic model...")
        create_semantic_model_from_bim(
            dataset=backup_name,
            bim_file=bim_file,
            workspace=backup_workspace,
        )

        # Resolve backup model ID
        backup_model_id = fabric.resolve_dataset_id(backup_name, backup_workspace)
        backup_items = [backup_model_id]

        # Clone report (Import mode only)
        if backup_model_and_report:
            print("Cloning report...")
            clone_report(
                report=model,
                cloned_report=backup_name,
                workspace=model_workspace,
                target_workspace=backup_workspace,
                target_dataset=backup_name,
                target_dataset_workspace=backup_workspace,
            )

            backup_report_id = fabric.resolve_item_id(backup_name, "Report", backup_workspace)
            backup_items.append(backup_report_id)
        else:
            backup_report_id = None

        # Move to folder
        if backup_folder:
            print(f"Moving to folder '{backup_folder}'...")
            move_items_to_folder(
                item_ids=backup_items,
                folder=backup_folder,
                workspace=backup_workspace,
                dry_run=dry_run
            )

        print(f"Backup created: {backup_name}")

        return {
            "backup_model_id": backup_model_id,
            "backup_model_name": backup_name,
            "backup_report_id": backup_report_id,
            "backup_report_name": backup_name,
            "backup_workspace": backup_workspace,
            "backup_folder": backup_folder,
        }

    except Exception as e:
        print(f"Backup failed: {e}")
        return None

# %% [markdown]
# ## Main function

# %%
def copy_rls(
    target_model: str,
    target_workspace: str,
    ref_model: str,
    ref_workspace: str,
    backup_folder: str = None,
    dry_run: bool = True
) -> str:
    """
    Copy RLS configuration from a reference model to a target model.

    This workflow can create a backup, compare role definitions, replace roles
    when needed, remove existing target members, and then copy reference members
    to the target.

    Args:
        target_model: Target semantic model name or ID.
        target_workspace: Target workspace name or ID.
        ref_model: Reference semantic model name or ID.
        ref_workspace: Reference workspace name or ID.
        backup_folder: Optional backup folder name or path.
        dry_run: If True, print the planned changes without applying them.

    Returns:
        A status message describing the outcome.

    Example:
        >>> result_x = copy_rls(
        ...     target_model="model_a",
        ...     target_workspace="workspace_a",
        ...     ref_model="model_b",
        ...     ref_workspace="workspace_b",
        ...     backup_folder="folder_a",
        ...     dry_run=True
        ... )
        >>> print(result_x)
    """
    # Helper functions
    def divide_section():
        print("\n" + "="*70 + "\n")

    # Resolve parameters
    target_model = fabric.resolve_dataset_name(target_model, target_workspace)
    target_workspace = fabric.resolve_workspace_name(target_workspace)
    ref_model = fabric.resolve_dataset_name(ref_model, ref_workspace)
    ref_workspace = fabric.resolve_workspace_name(ref_workspace)

    # Resolve target model storage mode
    target_storage_mode = get_storage_mode(target_model, target_workspace)

    print(f"RLS ROLE MEMBER COPIER - {'DRY RUN' if dry_run else 'EXECUTING'}")

    divide_section()

    print(f"Reference model: {ref_model}")
    print(f"Target model: {target_model}")
    print(f"Target model storage mode: {target_storage_mode}")
    
    divide_section()

    # Step 1: Backup (if executing)
    print("STEP 1: Creating backup...")
    backup_result = backup_model(
        model=target_model,
        model_workspace=target_workspace,
        backup_workspace=target_workspace,
        backup_folder=backup_folder,
        storage_mode=target_storage_mode,
        dry_run=dry_run
    )

    divide_section()
    
    # Step 2: Compare roles (only roles with a definition are compared, roles with no role definition will be ignored as they do not have RLS effect)
    print("STEP 2: Comparing roles...") 
    print("🔔 NOTICE: only roles with a definition are compared, roles with no role definition will be ignored as they do not have RLS effect")
    has_role_def_diff, role_def_comparison = compare_roles(
        target_model, target_workspace, 
        ref_model, ref_workspace, 
        include_role_def=True
    )

    if has_role_def_diff:
        print("Role definitions don't match!")
        print(f"  Reference only: {role_def_comparison['reference_only']}")
        print(f"  Target only: {role_def_comparison['target_only']}")
    else:
        print("Roles definition match")

    divide_section()
    
    # Step 3: Replace roles
    if has_role_def_diff:
        print("STEP 3: Replacing roles...")
        removed_roles = remove_role(target_model, target_workspace, remove_all=True, dry_run=dry_run)
        copied_roles = copy_role(target_model, target_workspace, ref_model, ref_workspace, dry_run=dry_run)
    else:
        print("STEP 3: Skip replacing roles...")

    divide_section()
    
    # Step 4: Remove existing members
    print("STEP 4: Removing existing members from target...")
    removed_role_members = remove_role_members(target_model, target_workspace, remove_all=True, dry_run=dry_run)

    divide_section()

    # Step 5: Copy members
    print("STEP 5: Copying members from reference to target...")
    ref_members = get_role_members(ref_model, ref_workspace, output_option='list')
    added_role_members = add_role_members(target_model, target_workspace, add_members=ref_members, dry_run=dry_run)
    
    divide_section()

    # Summary
    if dry_run:
        output_message = "DRY RUN complete - Review output above"
    else:
        output_message = f"SUCCESS - Copied row-level security configuration from '{ref_model}' to '{target_model}'"
    
    print(output_message)
    return output_message

# %% [markdown]
# # MAIN

# %%
result = copy_rls(
    target_model=MODEL,
    target_workspace=MODEL_WORKSPACE,
    ref_model=REF_MODEL,
    ref_workspace=REF_WORKSPACE, 
    backup_folder=BACKUP_FOLDER,
    dry_run=DRY_RUN
)

# %% [markdown]
# # Output

# %%
# Check if notebook is interactive session
interactive_run = nbutl.runtime.context["isForInteractive"]

if interactive_run:
    print(result)
else:
    nbutl.notebook.exit(result)
